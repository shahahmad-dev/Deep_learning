# %%
# !pip install -q numpy pandas matplotlib seaborn scipy scikit-learn \
# tensorflow keras \
# torch torchvision torchaudio \
# opencv-python pillow scikit-image albumentations \
# nltk spacy gensim transformers datasets sentencepiece \
# optuna shap lime \
# fastapi uvicorn streamlit gradio mlflow \
# librosa soundfile

# %%
# import libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.utils import to_categorical

# # load dataset mnist
# (x_train, y_train), (x_test, y_test) = mnist.load_data()

# # prepocessing
# x_train = x_train/ 255.0
# x_test = x_test / 255.0
# y_train = to_categorical(y_train, 10)
# y_test = to_categorical(y_test, 10)

# # define the model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
