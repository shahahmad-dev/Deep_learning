# %% [markdown]
# # 📈 Prophet Model for Time Series Forecasting
#
# <img src="https://images.unsplash.com/photo-1518186233392-c232efbf2373" width="600">
#
# **Prophet** is an open-source forecasting tool developed by **Facebook (Meta)**

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import files
upload = files.upload()
#

# %%
df_train = pd.read_csv('DailyDelhiClimateTest.csv', index_col='date', parse_dates=True)
df_test = pd.read_csv('DailyDelhiClimateTrain.csv', index_col='date', parse_dates=True)

# %% [markdown]
# # 📊 Dataset Basic Overview
#
# <img src="https://images.unsplash.com/photo-1551288049-bebda4e38f71" width="600">

# %%
print('Describe:\n', df_test.describe())
print('---------------------------------')

print('Info:')
df_test.info()
print('---------------------------------')

print('Shape:\n', df_test.shape)
print('---------------------------------')

print('Head:\n', df_test.head())

# %%
print('Describe:\n', df_train.describe())
print('---------------------------------')

print('Info:')
df_train.info()
print('---------------------------------')

print('Shape:\n', df_train.shape)
print('---------------------------------')

print('Head:\n', df_train.head())

# %% [markdown]
# # 📊 Plotting the Time Series Data
#
#
# <img src="https://images.unsplash.com/photo-1543286386-713bdd548da4" width="600">

# %%
# Drow a line plot
sns.set(rc={'figure.figsize':(16,8)}, font_scale=0.8, style='darkgrid')
sns.lineplot(data=df_test, x='date', y='meantemp')
